# %% [markdown]
# <a href="https://colab.research.google.com/github/Ventlious/learn-tensorflow/blob/master/ML_lab_05_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import numpy as np

# %%
xy = np.loadtxt('/content/gdrive/My Drive/data/data-03-diabetes.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]
print(x_data.shape, y_data.shape)
# Out:
# (759, 8) (759, 1)

# %%
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1,input_dim=8))
tf.model.add(tf.keras.layers.Activation('sigmoid'))

tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01),  metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 9
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=500)

# accuracy!
print("Accuracy: {0}".format(history.history['accuracy'][-1]))

# predict a single data point
y_predict = tf.model.predict([[0.176471, 0.155779, 0, 0, 0, 0.052161, -0.952178, -0.733333]])
print("Predict: {0}".format(y_predict))
# Out:
# Epoch 1/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5547
# Epoch 2/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6689 - accuracy: 0.5995
# Epoch 3/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6528 - accuracy: 0.6271
# Epoch 4/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6402 - accuracy: 0.6509
# Epoch 5/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6301 - accuracy: 0.6614
# Epoch 6/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6219 - accuracy: 0.6693
# Epoch 7/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6154 - accuracy: 0.6733
# Epoch 8/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6100 - accuracy: 0.6798
# Epoch 9/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6055 - accuracy: 0.6877
# Epoch 10/500
# ...
