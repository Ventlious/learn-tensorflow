# %% [markdown]
# <a href="https://colab.research.google.com/github/Ventlious/learn-tensorflow/blob/master/XOR_on_single_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(activation='sigmoid',units=1))

model.compile(optimizer=tf.keras.optimizers.Adam(0.1),
              loss='mse',
              metrics=['accuracy'])
model.fit(x_data, y_data, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2540 - accuracy: 0.7500
# Epoch 4/100
# 1/1 [==============================] - 0s 999us/step - loss: 0.2526 - accuracy: 0.7500
# Epoch 5/100
# 1/1 [==============================] - 0s 966us/step - loss: 0.2513 - accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2505 - accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2504 - accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 880us/step - loss: 0.2506 - accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2508 - accuracy: 0.5000
# Epoch 10/100
# ...
