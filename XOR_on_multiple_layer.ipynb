# %% [markdown]
# <a href="https://colab.research.google.com/github/Ventlious/learn-tensorflow/blob/master/XOR_on_multiple_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(activation='sigmoid',units=5))
model.add(tf.keras.layers.Dense(activation='sigmoid',units=1))

model.compile(optimizer=tf.keras.optimizers.Adam(0.1),
              loss='mse',
              metrics=['accuracy'])
model.fit(x_data, y_data, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2520 - accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 897us/step - loss: 0.2474 - accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 894us/step - loss: 0.2469 - accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 977us/step - loss: 0.2463 - accuracy: 0.2500
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2445 - accuracy: 0.2500
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 885us/step - loss: 0.2404 - accuracy: 0.5000
# Epoch 10/500
# ...

# %%
model.predict(x_data)
# Out:
# array([[0.00481558],
#        [0.9956481 ],
#        [0.9864137 ],
#        [0.01696486]], dtype=float32)
